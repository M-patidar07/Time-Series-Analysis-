# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\mahim\AppData\Local\Temp\ipykernel_20760\1943643728.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df1 = pd.read_csv("EV Stats.csv")
df2 = pd.read_csv("ElectricCarData_Norm.csv")
df3 = pd.read_csv("Indian automoble buying behavour study 1.0.csv")

# %%
df1[['State' ,'Total in state']]
# Out:
#                         State  Total in state
# 0              Andhra Pradesh            9492
# 1                       Assam            1875
# 2                       Bihar            3171
# 3                Chhattisgarh            4234
# 4                       Delhi           19381
# 5                         Goa             514
# 6                     Gujarat           31267
# 7                     Haryana           23589
# 8            Himachal Pradesh              98
# 9             Jammu & Kashmir             438
# 10                  Jharkhand            1710
# 11                  Karnataka           13386
# 12                     Kerala           11202
# 13             Madhya Pradesh            6461
# 14                Maharashtra           34013
# 15                    Manipur              52
# 16                  Meghalaya               6
# 17                   Nagaland              24
# 18                     Odisha            3863
# ...

# %%
df1.tail()
# Out:
#     Sl. No                      State  \
# 26      27                West Bengal
# 27      28  Andaman & Nicobar islands
# 28      29                 Chandigarh
# 29      30     Dadra and Nagar Haveli
# 30      31                      Total
#
#     Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 26                                               1451
# 27                                                  0
# 28                                                612
# 29                                                  4
# 30                                              27549
#
#     Two Wheelers (Category L2 (CMVR))  \
# 26                                 65
# 27                                  0
# 28                                 18
# 29                                  0
# 30                              14069
#
#     Two Wheelers (Max power not exceeding 250 Watts)  \
# 26                                             10781
# ...

# %%
    df2.head()
# Out:
#          Brand                          Model     Accel  TopSpeed   Range  \
# 0       Tesla   Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1  Volkswagen                       ID.3 Pure  10.0 sec  160 km/h  270 km
# 2    Polestar                               2   4.7 sec  210 km/h  400 km
# 3         BMW                            iX3    6.8 sec  180 km/h  360 km
# 4       Honda                              e    9.5 sec  145 km/h  170 km
#
#   Efficiency FastCharge              RapidCharge        PowerTrain  \
# 0  161 Wh/km   940 km/h  Rapid charging possible   All Wheel Drive
# 1  167 Wh/km   250 km/h  Rapid charging possible  Rear Wheel Drive
# 2  181 Wh/km   620 km/h  Rapid charging possible   All Wheel Drive
# 3  206 Wh/km   560 km/h  Rapid charging possible  Rear Wheel Drive
# 4  168 Wh/km   190 km/h  Rapid charging possible  Rear Wheel Drive
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
df3.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
len(df1), len(df2), len(df3)
# Out:
# (31, 103, 99)

# %% [markdown]
# DF1

# %%
# Plotting state v/S Total EVvehicles in state
df1["State"].dtype, df1["Total in state"].dtype

# x-axis = state
# y-axis = vehicles
# Out:
# (dtype('O'), dtype('int64'))

# %%
# Mean of total Sales from each state
column = df1["Total in state"][:-1]
average = np.mean(column)
print(f"Mean sales of all the States combined is : {average}")
# Out:
# Mean sales of all the States combined is : 8695.433333333332

# %%
y = df1["Total in state"][:30]
x = df1["State"][:30]

plt.bar(x, y)
plt.xlabel("State")
plt.ylabel("Total EV's in state")
plt.axhline(y.mean(), color='r', linestyle='--')
#plt.axhline(y.median(), color='g', linestyle='--')
plt.title("State V/S Total EV's in state")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Horizonal red-dotted line represents the mean....so the state having the sales above mean have higher chance of increased sales in the upcoming year as well

# %%
column = df1["Total in state"][:-1]
average = np.mean(column)
states_with_greater_sales = df1["State"][:30][df1["Total in state"] > average]
states_with_greater_sales
# Out:
# 0     Andhra Pradesh
# 4              Delhi
# 6            Gujarat
# 7            Haryana
# 11         Karnataka
# 12            Kerala
# 14       Maharashtra
# 20         Rajasthan
# 21        Tamil Nadu
# 22         Telangana
# 24     Uttar Pradesh
# 26       West Bengal
# Name: State, dtype: object

# %%
['Andhra Pradesh','Assam','Bihar','Chhattisgarh','Delhi','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu & Kashmir','Jharkhand',
 'Karnataka','Kerala','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Nagaland','Odisha','Punjab','Rajasthan','Tamil Nadu',
 'Telangana','Tripura','Uttar Pradesh','Uttarkhand','West Bengal','Andaman & Nicobar islands','Chandigarh','Dadra and Nagar Haveli']

# %% [markdown]
# We can see Maharashtra, Gujrat and Uttar Pradesh has the highest registered EV sales
# and Manipur, Meghalaya and  Himachal Pradesh has lowest EV registered

# %%
df1['State'].tail(15)
# Out:
# 16                    Meghalaya
# 17                     Nagaland
# 18                       Odisha
# 19                       Punjab
# 20                    Rajasthan
# 21                   Tamil Nadu
# 22                    Telangana
# 23                      Tripura
# 24                Uttar Pradesh
# 25                   Uttarkhand
# 26                  West Bengal
# 27    Andaman & Nicobar islands
# 28                   Chandigarh
# 29       Dadra and Nagar Haveli
# 30                        Total
# Name: State, dtype: object

# %%
df = ['AP','AS','BR','CG','DL','GA','GJ','HR','HP','JK','JH','KA','KL','MP','MH','MN','ML','NL','OR','PB','RJ','TN','TG','TR','UP','UK','WB','AN','CH','DH']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df = pd.Series[['AP','AS','BR','CG','DL','GA','GJ','HR','HP','JK','JH','KA','KL','MP','MH','MN','ML','NL','OR','PB','RJ','TN','TG','TR','UP','UK','WB','AN','CH','DH']]
#
# TypeError: type 'Series' is not subscriptable

# %%
df1.replace(['Andhra Pradesh','Assam','Bihar','Chhattisgarh','Delhi','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu & Kashmir','Jharkhand',
 'Karnataka','Kerala','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Nagaland','Odisha','Punjab','Rajasthan','Tamil Nadu',
 'Telangana','Tripura','Uttar Pradesh','Uttarkhand','West Bengal','Andaman & Nicobar islands','Chandigarh','Dadra and Nagar Haveli'],
  ['AP','AS','BR','CG','DL','GA','GJ','HR','HP','JK','JH','KA','KL','MP','MH','MN','ML','NL','OR','PB','RJ','TN','TG','TR','UP','UK','WB','AN','CH','DH'] ,
  inplace=True)

# %% [markdown]
# State V/S every ev vehicle category

# %%
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules
plt.figure(figsize=(6, 5))
x = df1["State"][:30]
y = df1["Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules"][:30]

plt.bar(x,y)
plt.xlabel("State")
plt.ylabel("Total Two Wheeler (Category-I) in state")
plt.title("State V/S Two Wheeler (Category-I: Category L1 & L2 as per central motor vehicles rules)")
plt.xticks(rotation=90)
plt.show()

# %%
df1[4:5]
# Out:
#    Sl. No  State  \
# 4       5  Delhi
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 4                                               1395
#
#    Two Wheelers (Category L2 (CMVR))  \
# 4                                251
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 4                                              5018
#
#    Three Wheelers (Category L5 slow speed as per CMVR)  \
# 4                                                  0
#
#    Three Wheelers (Category L5 as per CMVR)  \
# 4                                         1
#
#    Passenger Cars (Category M1 as per CMVR)  Buses  Total in state
# 4                                     12695     21           19381

# %%
# Two Wheelers (Category L2 (CMVR))

x = df1["State"][:30]
y = df1["Two Wheelers (Category L2 (CMVR))"][:30]
plt.figure(figsize=(6, 5))
plt.bar(x,y)
plt.xlabel("State")
plt.ylabel("Total Two Wheeler (Category-II) in state")
plt.title("State V/S Two Wheeler (Category-II: Category L2 (CMVR))")
plt.xticks(rotation=90)
plt.show()

# %%
# Two Wheelers (Max power not exceeding 250 Watts)

x = df1["State"][:30]
y = df1["Two Wheelers (Max power not exceeding 250 Watts)"][:30]
plt.figure(figsize=(6, 5))
plt.bar(x,y)
plt.xlabel("State")
plt.ylabel("Total Two Wheeler (Category-III) in state")
plt.title("State V/S Two Wheeler (Category-III: Max power not exceeding 250 Watts)")
plt.xticks(rotation=90)
plt.show()

# %%
# Three Wheelers (Category L5 slow speed as per CMVR)

x = df1["State"][:30]
y = df1["Three Wheelers (Category L5 slow speed as per CMVR)"][:30]

plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()

# %%
# Passenger Cars (Category M1 as per CMVR)

x = df1["State"][:30]
y = df1["Passenger Cars (Category M1 as per CMVR)"][:30]
plt.figure(figsize=(6, 5))
plt.bar(x,y)
plt.xlabel("State")
plt.ylabel("Total Passenger Cars in state")
plt.title("State V/S Total Passenger Cars ")
plt.xticks(rotation=90)
plt.show()

# %%
# Buses

x = df1["State"][:30]
y = df1["Buses"][:30]
plt.figure(figsize=(6, 5))
plt.bar(x,y)
plt.xlabel("State")
plt.ylabel("Total Buses in state")
plt.title("State V/S Buses")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# DF3

# %%
df3.head(3)
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000

# %%
# Columns of data
df3.columns
# Out:
# Index(['Age', 'Profession', 'Marrital Status', 'Education', 'No of Dependents',
#        'Personal loan', 'House Loan', 'Wife Working', 'Salary', 'Wife Salary',
#        'Total Salary', 'Make', 'Price'],
#       dtype='object')

# %%
# Additional Information about the data
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB

# %%
# Checking Null values
df3.isnull().sum()
# Out:
# Age                 0
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# Wife Working        0
# Salary              0
# Wife Salary         0
# Total Salary        0
# Make                0
# Price               0
# dtype: int64

# %% [markdown]
# Some Visualizations regarding the data

# %%
sns.countplot(data=df3, x="Profession", hue="Profession", palette="flare", legend=False)
plt.title("Profession data")
plt.xlabel("Profession")
plt.ylabel("Count")
plt.show()

# %%
# Histogram of Ages
sns.histplot(data=df3, x="Age", bins=10, color="yellow", edgecolor="blue")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Numbers")
plt.show()

# %%
# Marital Status
sns.countplot(data=df3, x="Marrital Status", palette="dark")
plt.title("Marrital Status Analysis")
plt.xlabel("Marrital Status")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\sampu\AppData\Local\Temp\ipykernel_16368\3935937301.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df3, x="Marrital Status", palette="dark")

# %%
# Salary Analysis
sns.kdeplot(df3["Salary"])

plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Density")

plt.show()

# %% [markdown]
# Car Make Comparison

# %%
sns.countplot(data=df3,x="Make")
plt.title("Car Make Comparison")
plt.xlabel("Make")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
df_encoded = pd.get_dummies(df3)

# Finding Correlation matrix
data_corr = df_encoded.corr()

plt.figure(figsize=(16,10))
plt.title("Correlation Matrix HeatMap")

sns.heatmap(data_corr, annot=True, fmt=".2f", cmap="inferno", linewidth=0.5)

plt.xticks(rotation=90)
plt.yticks(rotation=0)

plt.show()
